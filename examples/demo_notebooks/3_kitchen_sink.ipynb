# %% [markdown]
# # Kitchen Sink - Multiple Issues

# %%
import pandas as pd
from transformers import AutoModel
import internal_custom_lib

# %%
# Hardcoded secrets - security issue
AWS_KEY = 'AKIAIOSFODNN7EXAMPLE'
API_TOKEN = 'sk-proj-abcdefghijklmnop1234567890'

# %%
# Hardcoded paths - portability issue
data_path = '/Users/datascientist/data/train.csv'
model_path = '/home/user/models/checkpoint.pt'

# %%
# Large model - resource issue
model = AutoModel.from_pretrained('meta-llama/Llama-2-13b')
df = pd.read_csv(data_path)
print(df.head())
